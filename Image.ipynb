# %%
import os
print(os.path.exists('C:/Users/TARUN KUMAR SARKAR/OneDrive/Pictures/Screenshot 2023-07-08 153831.jpeg'))
# Out:
# True

# %%
from PIL import Image

# Create an 8x8 pixel image with a single color (e.g., red)
image = Image.new('RGB', (8, 8), (255, 0, 0))  # RGB color for red
image.show()  # Display the image

# %%
import numpy as np
from PIL import Image
filename = "C:/Users/TARUN KUMAR SARKAR/OneDrive/Pictures/Screenshot 2023-07-08 153831.jpeg"
im = Image.open(filename)  # download it manually
im.size
# Out:
# (288, 372)

# %%
im = np.array(im.getdata()).reshape(864, 372)
im
# Out:
# array([[255, 251, 251, ..., 254, 254, 252],
#        [254, 254, 252, ...,  43,  46,  61],
#        [ 44,  46,  61, ..., 251, 252, 255],
#        ...,
#        [237, 239, 251, ..., 218, 221, 240],
#        [218, 221, 240, ...,  58,  88, 140],
#        [ 72,  99, 152, ..., 220, 220, 232]])

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn")
plt.rcParams["axes.grid"] = False
plt.imshow(im, cmap="gray")
plt.rcParams["axes.grid"] = True
plt.show()

# %%
g=im.flatten()
