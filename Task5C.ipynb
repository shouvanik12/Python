# %% [markdown]
# # Task 5C: Daily and Monthly Mean Wind Speeds for Three Airports- Tableau

# %% [markdown]
# ## Shouvanik Sarkar, Student ID: 225174439, email id: s225174439@deakin.edu.au

# %% [markdown]
# ### Daily and Monthly Mean Wind Speed for three airports

# %% [markdown]
# Tableau Dashboard Link:
#     https://public.tableau.com/shared/6Y84D939N?:display_count=n&:origin=viz_share_link

# %% [markdown]
# ### Calculated Fields
#
# ![image.png](attachment:9f0e6654-83d2-4d15-87d6-09d8e8fe0402.png)

# %% [markdown]
# ### Daily Mean Wind Speeds
# ![image.png](attachment:794ce862-2e33-488a-bb85-d27f5d3cafc7.png)

# %% [markdown]
# ### Top 10 windiest days
# ![image.png](attachment:86453f1d-0777-4ac0-aac4-aff27112babd.png)

# %% [markdown]
# ### Monthly Mean Average wind speed
# ![image.png](attachment:6be161a6-c895-4e66-8ce0-a4205ea89e4a.png)

# %% [markdown]
# ### Dashboard
# ![image.png](attachment:53546b1a-aced-40d7-a509-cb35d545e58f.png)
